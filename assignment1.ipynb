# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Do the following operation on Iris dataset:
# 1. Read the dataset to python environment.

# %%
"""Reading the dataset.
Giving readable names to columns"""

names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
data=pd.read_excel("/content/iris.xls", names = names)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset.

# %%
#displaying all column names
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
#calculating mean of each columns
data.mean(numeric_only=True)
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset

# %%
#checking for any null values in the iris dataset
data.isnull()
data.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
#using scatter plot
plt.scatter(data['petal_width'],data['sepal_length'],color='Orange',edgecolor='red')
plt.title('Petal Width v/s Sepal Length')
plt.xlabel('Petal Width')
plt.ylabel('Sepal Length')
plt.show()

# %%
#Plotting histograms on iris features
data.hist(edgecolor='black', linewidth=1)
plt.show()

# %%
#plotting box plot
data.boxplot(by = 'species', figsize = (20,10))
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
