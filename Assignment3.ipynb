# %%
# importing libraries
import pandas as pd
# loading the dataset
data=pd.read_csv('/content/StudentsPerformance.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# An Institution wishes to find out their student’s ability in mathematics, reading
# and writing skills. The Institution wants to do an exploratory study to check the
# following information.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 8)

# %% [markdown]
# 1. Find out how many males and females participated in the test.

# %%
# Counting number of males and females.
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# 2. What do you think about the students' parental level of education?

# %%
# Students Parental level of education
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data.groupby('parental level of education').describe()
# Out:
#                             math score                                     \
#                                  count       mean        std   min    25%
# parental level of education
# associate's degree               222.0  67.977477  15.108190  26.0  57.00
# bachelor's degree                118.0  69.288136  15.164117  29.0  61.00
# high school                      196.0  61.821429  15.160466   8.0  53.75
# master's degree                   59.0  70.254237  14.843544  40.0  57.00
# some college                     226.0  67.128319  14.871790  11.0  59.00
# some high school                 179.0  63.134078  16.602894   0.0  53.00
#
#                                                reading score             ...  \
#                               50%   75%    max         count       mean  ...
# parental level of education                                              ...
# associate's degree           67.0  80.0  100.0         222.0  71.018018  ...
# bachelor's degree            68.0  79.0  100.0         118.0  73.000000  ...
# high school                  63.0  72.0   99.0         196.0  64.602041  ...
# master's degree              73.0  81.0   95.0          59.0  75.949153  ...
# some college                 68.0  76.0  100.0         226.0  69.566372  ...
# some high school             65.0  74.0   97.0         179.0  66.759777  ...
#
#                                           writing score                        \
#                                75%    max         count       mean        std
# parental level of education
# associate's degree           81.00  100.0         222.0  70.031532  14.260787
# bachelor's degree            82.75  100.0         118.0  73.381356  14.728262
# high school                  74.25   99.0         196.0  62.403061  14.165172
# master's degree              84.50  100.0          59.0  75.677966  13.730711
# some college                 80.00  100.0         226.0  69.035398  15.089911
# some high school             79.00  100.0         179.0  64.888268  15.736197
#
#
#                               min    25%   50%   75%    max
# parental level of education
# associate's degree           35.0  58.25  71.5  80.0  100.0
# bachelor's degree            38.0  62.50  74.0  83.0  100.0
# high school                  15.0  52.00  64.0  73.0  100.0
# master's degree              46.0  67.00  75.0  85.0  100.0
# some college                 19.0  60.00  70.0  79.0   99.0
# some high school             10.0  54.00  66.0  77.0  100.0
#
# [6 rows x 24 columns]

# %% [markdown]
# 3.Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
data.groupby('gender').mean()
# Out:
# <ipython-input-12-906c82ffe320>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('gender').mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
data.groupby('test preparation course').mean()
# Out:
# <ipython-input-21-e468d0dc9a30>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('test preparation course').mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# 4. What do you think about the scoring variation for math, reading and writing
# based on
# ● Gender
# ● Test preparation course

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.groupby(['gender','test preparation course']).var()
# Out:
# <ipython-input-15-337338ee36ae>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender','test preparation course']).var()
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687

# %% [markdown]
# 5.**The** management needs your help to give bonus points to the top 25% of
# students based on their math score, so how will you help the management
# to achieve this

# %%
b=data['math score'].count()
percent=(b)*(25/100)
percent
# Out:
# 250.0

# %%
data1=data.sort_values(by='math score')
data2=data1.head(250)
data2.assign(bonus_point=10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 3    female        group B                some college      standard
# 51   female        group C            some high school  free/reduced
# 2    female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 151  female        group D          associate's degree  free/reduced
# 152  female        group E             master's degree  free/reduced
# 162  female        group E                 high school  free/reduced
# 161  female        group E                 high school  free/reduced
# 160  female        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none           0             17             10
# 1                      none           8             24             23
# 3                      none          11             38             32
# 51                     none          13             41             51
# 2                      none          18             32             28
# ..                      ...         ...            ...            ...
# 151                    none          56             65             63
# 152                    none          56             72             65
# 162               completed          57             75             73
# 161                    none          57             58             57
# 160               completed          57             68             73
#
#      bonus_point
# 0             10
# 1             10
# 3             10
# 51            10
# 2             10
# ..           ...
# 151           10
# 152           10
# 162           10
# 161           10
# 160           10
#
# [250 rows x 9 columns]
