# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
#creating a new dataframe df from this data
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
df = pd.DataFrame(data, index=['a','b','c','d', 'e', 'f', 'g', 'h', 'i', 'j'])
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
#Displaying a summary of the basic information of dataframe df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
#Returning the First 3 rows of the df
df.iloc[:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
#Displaying animal and age columns from df.
df.iloc[:,[0,1]]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
#Displaying the required data
df.iloc[[3,4,8],[0,1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
#printing only the rows where the number of visits is greater than 3.
print('Rows which has number of visits greater than 3: ')
print(df[df['visits']>3])
# Out:
# Rows which has number of visits greater than 3:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
#Selecting the rows where the age is missing.
print(df[df['age'].isnull()])
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
#To select the rows where the animal is a cat and the age is less than 3.
print(df[(df['animal'] == 'cat') & (df['age']<3)])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
#To select the given rows
print(df[df['age'].between(2, 4)])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
#To change the age in row 'f' to 1.5
df.loc['f', 'age'] = 1.5
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
#To calculate the sum of all visits in df
print('Sum of all visits :', df['visits'].sum())
# Out:
# Sum of all visits : 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
#To calculate the mean age for each different animals in df
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
#Appending a new row 'k' to df
df.loc['k'] = ['cat', 1.5, 3, 'yes']
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k    cat  1.5       3      yes

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
#To count the number of each type of animals in df
df['animal'].value_counts()
# Out:
# cat      5
# dog      4
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
#Sorting
df.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# k    cat  1.5       3      yes
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
#Replacing an entire column values to boolean values
df['priority'] = df['priority'].replace({'yes': 'True', 'no': 'False'})
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1     True
# b    cat  3.0       3     True
# c  snake  0.5       2    False
# d    dog  NaN       3     True
# e    dog  5.0       2    False
# f    cat  1.5       3    False
# g  snake  4.5       1    False
# h    cat  NaN       1     True
# i    dog  7.0       2    False
# j    dog  3.0       1    False
# k    cat  1.5       3     True

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
#Changing the entries with 'snake' to 'python'
df['animal'] = df['animal'].replace('snake', 'python')
print(df)
# Out:
#    animal  age  visits priority
# a     cat  2.5       1     True
# b     cat  3.0       3     True
# c  python  0.5       2    False
# d     dog  NaN       3     True
# e     dog  5.0       2    False
# f     cat  1.5       3    False
# g  python  4.5       1    False
# h     cat  NaN       1     True
# i     dog  7.0       2    False
# j     dog  3.0       1    False
# k     cat  1.5       3     True

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
#Loading the ny-flights dataset to Python
data1=pd.read_csv('/content/ny-flights.csv')
data1.head()
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
#Printing the Name of Airline which is present maximum times.
items_counts = data1['airline_id'].value_counts()
max_item = items_counts.max()
print("Name of Airline which is present maximum times is :",max_item)
# Out:
# Name of Airline which is present maximum times is : 4902

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
#Drawing a plot using matplotlib between dep_delay and arr_delay
import matplotlib.pyplot as plt
plt.plot(data1['dep_delay'],data1['arr_delay'])
plt.title('Departure delay V/s Arrival Delay')
plt.xlabel('Arrival Delay')
plt.ylabel('Departure Delay')
# Out:
# Text(0, 0.5, 'Departure Delay')
